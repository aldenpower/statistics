# %%
import pandas as pd
import numpy as np

# %%
cur = pd.read_csv('/media/mr-alden/backup/onedrive/reps/cur/data/2022/personal.csv')

# %%
data = pd.Series(np.random.randn(9), index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'], [1, 2, 3, 1, 3, 1, 2, 2, 3]])
data.index
data['a']
data['b']
data['b' : 'c']
data.loc[['b', 'd']]
data.loc[:, 2]
data.unstack().stack()
# Out:
# a  1   -1.955653
#    2   -0.349356
#    3    0.328458
# b  1   -0.585232
#    3   -0.371984
# c  1    0.059581
#    2   -2.047980
# d  2   -0.805002
#    3    0.184583
# dtype: float64

# %%
sorted = cur.sort_values(by = ['Sist', 'Fonte', 'Dia'], ascending = True)
sorted.index
# Out:
# Int64Index([19, 20, 15, 14, 18, 28, 29, 22, 24, 25, 26, 27, 21, 32, 16, 33, 36,
#             17, 44, 45, 46, 47, 48, 31, 49, 23,  6,  9,  7, 30, 42, 43,  1, 35,
#             37,  0,  8, 10,  3,  5,  4, 11, 12, 38,  2, 13, 39, 41, 40, 34],
#            dtype='int64')

# %%
idnexe = sorted.set_index([sorted['Sist'], sorted['Fonte']])
idnexe
# Out:
#                                                                   Disc   Sist  \
# Sist  Fonte
# Dp    cash                                                  Vitamina D     Dp
#       cash                                                        Açai     Dp
#       cash                           Almoço 2 águas 20L e compras rios     Dp
#       cash                                  Combustível oroch pedagios     Dp
#       ccnubank                                       Compras atakarejo     Dp
#       ccnubank               Almoco isabelle cafe Kopen estacionamento     Dp
#       ccnubank                              Filme o senhor dos aneis 1     Dp
#       ccnubank                                 Pizza dnapoli bp select     Dp
#       ccnubank                          Ferramentas ferro solda e mais     Dp
#       ccnubank                                         Recarga celular     Dp
#       ccnubank                  Sete habitos das pessoas mais eficazes     Dp
# ...

# %%
disc.str.contains('saldo')
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37     True
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: Disc, dtype: bool

# %%
cur
# Out:
#                                                  Disc   Sist  \
# 0                                      saldo anterior    Opf
# 1                                      saldo anterior    Opf
# 2                                      saldo anterior    Opf
# 3                                      saldo anterior    Opf
# 4                                      saldo anterior    Opf
# 5                                      saldo anterior    Opf
# 6            Juros s/ capital próprio 50 BRITUBACNOR4    Inv
# 7                  Retirada de saldo de tesouro selic    Inv
# 8                  Recebimento de saldo tesouro selic    Opf
# 9                             Prov irrf s/ renda fixa    Inv
# 10                        Saída de saldo para Nuconta    Opf
# 11                  Recebimento de saldo da easynvest    Opf
# 12                             Saída para sistema faz    Opf
# 13                                    Aluguel ap. 403     Pr
# ...

# %%
df = pd.DataFrame({'k1' : ['one', None] * 5, 'k2' : ['three', 'a'] * 5})
rand = pd.DataFrame(np.random.randn(7, 3))
rand
# Out:
#           0         1         2
# 0 -0.208172 -0.185542  0.895656
# 1  1.408961  0.189968  1.538610
# 2 -0.835822  2.155685 -1.132575
# 3  0.614122 -0.023387  0.049809
# 4  0.457751  0.118915 -0.783062
# 5 -1.133894 -0.077523  1.437965
# 6 -1.303685 -0.731608 -1.643259

# %%
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon','Pastrami', 'corned beef', 'Bacon', 'pastrami', 'honey ham', 'nova lox'],
'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})

data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
rand.iloc[:4, 1] = None
rand
# Out:
#           0         1         2
# 0 -0.208172       NaN  0.895656
# 1  1.408961       NaN  1.538610
# 2 -0.835822       NaN -1.132575
# 3  0.614122       NaN  0.049809
# 4  0.457751  0.118915 -0.783062
# 5 -1.133894 -0.077523  1.437965
# 6 -1.303685 -0.731608 -1.643259

# %%
no_na = df.dropna()
no_na
# Out:
#     k1     k2
# 0  one  three
# 1  NaN      a
# 2  one  three
# 3  NaN      a
# 4  one  three
# 5  NaN      a
# 6  one  three
# 7  NaN      a
# 8  one  three
# 9  NaN      a

# %%
ser = pd.Series(['aard', 'arti', np.nan, 'avocado', None])
ser
# Out:
# 0       aard
# 1       arti
# 2        NaN
# 3    avocado
# 4       None
# dtype: object

# %%
ser.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
ser[0]
# Out:
# 'aard'
